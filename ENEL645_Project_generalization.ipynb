# %%
import numpy as np
import tensorflow as tf
import os
from os.path import isfile, join
import pandas as pd
import matplotlib.pylab as plt
from sklearn import preprocessing

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_folder = '/content/drive/MyDrive/Colab Notebooks/UAH-DRIVESET-v1'

# %%
def get_dataset(data_path, shape, train_per = 0.7, val_per = 0.1, test_per = 0.2):
    # initialize data variable as list
    X_train, Y_train, X_val, Y_val, X_test, Y_test = [], [], [], [], [], []

    for root, dirs, files in os.walk(data_path, topdown=False):
        if len(files) < 2:
            continue
        else:
            gps_df = get_data_list(root, shape)
            
            # train_split_index = int(train_per * len(gps_df))
            # val_split_index = int(val_per * len(gps_df)) + train_split_index
            if root.split("/")[-1].split("-")[2] in ['D1', 'D2', 'D3', 'D4']:
                X_train.extend(gps_df)
                for i in range(len(gps_df)):
                    Y_train.append([root.split("/")[-1].split("-")[2], get_trip_labels(root), get_road_type(root)])
            elif root.split("/")[-1].split("-")[2] == 'D5':
                X_val.extend(gps_df)
                for i in range(len(gps_df)):
                    Y_val.append([root.split("/")[-1].split("-")[2], get_trip_labels(root), get_road_type(root)])
            elif root.split("/")[-1].split("-")[2] == 'D6':
                X_test.extend(gps_df)
                for i in range(len(gps_df)):
                    Y_test.append([root.split("/")[-1].split("-")[2], get_trip_labels(root), get_road_type(root)])

    labels_columns = ["driver", "type", "road"]
    Y_train = pd.DataFrame(data= np.array(Y_train), columns=labels_columns)
    Y_val = pd.DataFrame(data= np.array(Y_val), columns=labels_columns)
    Y_test = pd.DataFrame(data= np.array(Y_test), columns=labels_columns)
    X_train = np.array(X_train)
    X_val = np.array(X_val)
    X_test = np.array(X_test)
    return X_train, Y_train, X_val, Y_val, X_test, Y_test


def get_data_list(root, shape):
    data_list = []
    gps_df = import_uah_trip_data(root)
    divisions = int(len(gps_df)/shape)
    gps_df = gps_df[:divisions * shape]
    for i in range(divisions):
      data_list.append(gps_df[shape * (i):shape * (i+1)])
    return data_list

def import_uah_trip_data(root_path):
    # import raw inertial data
    gps_file_path = os.path.join(root_path, "RAW_GPS.txt")
    gps_df = pd.read_csv(gps_file_path, sep=" ", header=None).iloc[:, 0:7]
    # add the column names
    gps_df.columns = [
        "timestamp",
        "speed",
        "latitude",
        "longitude",
        "altitude",
        "verticalAccuracy",
        "horizentalAccuracy",
    ]
    dataFrame = pd.DataFrame(data=gps_df, columns=gps_df.columns)
    return dataFrame

def get_trip_labels(file_path):
    if "NORMAL" in file_path:
        label = "NORMAL"
    elif "AGGRESSIVE" in file_path:
        label = "AGGRESSIVE"
    elif "DROWSY" in file_path:
        label = "DROWSY"
    else:
        label = None
    return label


def get_road_type(file_path):
    if "SECONDARY" in file_path:
        return "secondary"
    elif "MOTORWAY" in file_path:
        return "motorway"
    else:
        return None

# %%
def normalization(X_train, X_val, X_test, type = 'min-max'):
    if type == 'min-max':
        for i in range(len(X_train[0,0])):
            train_min, train_max = X_train[:,0,i].min(),X_train[:,0,i].max() 
            X_train[:,0,i] = (X_train[:,0,i] - train_min)/(train_max - train_min)
            X_val[:,0,i] = (X_val[:,0,i] - train_min)/(train_max - train_min)
            X_test[:,0,i] = (X_test[:,0,i] - train_min)/(train_max - train_min)
    elif type == 'standardization':
        for i in range(len(X_train[0,0])):
            train_mean, train_std = X_train[:,0,i].mean(),X_train[:,0,i].std() 
            X_train[:,0,i] = (X_train[:,0,i] - train_mean)/train_std
            X_val[:,0,i] = (X_val[:,0,i] - train_mean)/train_std
            X_test[:,0,i] = (X_test[:,0,i] - train_mean)/train_std
    return X_train, X_val, X_test

# %%
def oneHotEndcoding(Y_train, Y_val, Y_test):
    Y_train_oh = pd.get_dummies(Y_train.type, prefix='type')
    Y_val_oh = pd.get_dummies(Y_val.type, prefix='type')
    Y_test_oh = pd.get_dummies(Y_test.type, prefix='type')
    return Y_train_oh, Y_val_oh, Y_test_oh

# %%
# def my_model_fully_connected(ishape, k = 2, lr = 1e-4, drop_out = 0.1, weight_decay = 1e-3):
#     model_input = tf.keras.layers.Input(shape=ishape)
#     model_input_flatten = tf.keras.layers.Flatten()(model_input)
#     l1 = tf.keras.layers.Dense(30, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(model_input_flatten)
#     l1_Batch = tf.keras.layers.BatchNormalization()(l1)
#     l1_dropOut = tf.keras.layers.Dropout(drop_out)(l1_Batch)

#     l2 = tf.keras.layers.Dense(30, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l1_dropOut)
#     l2_Batch = tf.keras.layers.BatchNormalization()(l2)
#     l2_dropOut = tf.keras.layers.Dropout(2*drop_out)(l2_Batch)

#     l3 = tf.keras.layers.Dense(30, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l2_dropOut)
#     l3_Batch = tf.keras.layers.BatchNormalization()(l3)
#     l3_dropOut = tf.keras.layers.Dropout(3*drop_out)(l3_Batch)

#     # l4 = tf.keras.layers.Dense(8*16, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l3_dropOut)
#     # l4_Batch = tf.keras.layers.BatchNormalization()(l4)
#     # l4_dropOut = tf.keras.layers.Dropout(3*drop_out)(l4_Batch)

#     # l5 = tf.keras.layers.Dense(8*8, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l4_dropOut)
#     # l5_Batch = tf.keras.layers.BatchNormalization()(l5)
#     # l5_dropOut = tf.keras.layers.Dropout(5*drop_out)(l5_Batch)

#     l6 = tf.keras.layers.Dense(30, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l3_dropOut)
#     l6_Batch = tf.keras.layers.BatchNormalization()(l6)
#     l6_dropOut = tf.keras.layers.Dropout(5*drop_out)(l6_Batch)

#     out = tf.keras.layers.Dense(k,activation = 'softmax')(l6_dropOut)
#     model = tf.keras.models.Model(inputs = model_input, outputs = out)
#     # opt_rms = tf.keras.optimizers.RMSprop(lr=lr,decay=1e-6)
#     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss='categorical_crossentropy', metrics = ["accuracy"])
    
#     return model

# %%
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
        possible_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
        predicted_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+tf.keras.backend.epsilon()))

# %%
def my_model_fully_connected(ishape, k = 3, lr = 1e-4, drop_out = 0.1, weight_decay = 1e-4):
    model_input = tf.keras.layers.Input(shape=ishape)
    model_input_flatten = tf.keras.layers.Flatten()(model_input)
    l1 = tf.keras.layers.Dense(512, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(model_input_flatten)
    l1_Batch = tf.keras.layers.BatchNormalization()(l1)
    # l1_dropOut = tf.keras.layers.Dropout(drop_out)(l1_Batch)

    l2 = tf.keras.layers.Dense(512, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l1_Batch)
    l2_Batch = tf.keras.layers.BatchNormalization()(l2)
    # l2_dropOut = tf.keras.layers.Dropout(2*drop_out)(l2_Batch)

    l3 = tf.keras.layers.Dense(256, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l2_Batch)
    l3_Batch = tf.keras.layers.BatchNormalization()(l3)
    # l3_dropOut = tf.keras.layers.Dropout(3*drop_out)(l3_Batch)

    l4 = tf.keras.layers.Dense(256, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l3_Batch)
    l4_Batch = tf.keras.layers.BatchNormalization()(l4)
    # l4_dropOut = tf.keras.layers.Dropout(4*drop_out)(l4_Batch)

    l5 = tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l4_Batch)
    l5_Batch = tf.keras.layers.BatchNormalization()(l5)
    # l5_dropOut = tf.keras.layers.Dropout(5*drop_out)(l5_Batch)

    l6 = tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l5_Batch)
    l6_Batch = tf.keras.layers.BatchNormalization()(l6)
    # l6_dropOut = tf.keras.layers.Dropout(5*drop_out)(l6_Batch)

    l7 = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l6_Batch)
    l7_Batch = tf.keras.layers.BatchNormalization()(l7)
    # l7_dropOut = tf.keras.layers.Dropout(3*drop_out)(l7_Batch)

    l8 = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l7_Batch)
    l8_Batch = tf.keras.layers.BatchNormalization()(l8)
    # l8_dropOut = tf.keras.layers.Dropout(5*drop_out)(l8_Batch)

    l9 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l8_Batch)
    l9_Batch = tf.keras.layers.BatchNormalization()(l9)
    # l9_dropOut = tf.keras.layers.Dropout(5*drop_out)(l9_Batch)

    l10 = tf.keras.layers.Dense(16, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l9_Batch)
    l10_Batch = tf.keras.layers.BatchNormalization()(l10)
    
    
    out = tf.keras.layers.Dense(k,activation = 'softmax')(l10_Batch)
    model = tf.keras.models.Model(inputs = model_input, outputs = out)
    opt_rms = tf.keras.optimizers.RMSprop(lr=lr,decay=1e-6)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss='categorical_crossentropy', metrics = ["accuracy", f1])
    return model

# %%
model_name_fcn = "team_4_FCN.h5"
def callbacks():
    early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 40)

    monitor = tf.keras.callbacks.ModelCheckpoint(model_name_fcn, monitor='val_loss',\
                                                verbose=0,save_best_only=True,\
                                                save_weights_only=True,\
                                                mode='min')
    # Learning rate schedule
    def scheduler(epoch, lr):
        if epoch%40 == 0:
            lr = lr/2
        return lr

    lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler,verbose = 0)
    
    return early_stop, monitor, lr_schedule

# %%
shape = 1
X_train, Y_train, X_val, Y_val, X_test, Y_test = get_dataset(data_folder, shape=shape)
X_train, X_val, X_test = normalization(X_train, X_val, X_test)
Y_train_oh, Y_val_oh, Y_test_oh = oneHotEndcoding(Y_train, Y_val, Y_test)
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (21141, 1, 7)
# (4529, 1, 7)
# (5299, 1, 7)

# %%
model_FC = my_model_fully_connected(ishape=(len(X_train[0]), len(X_train[0,0])))
early_stop, monitor, lr_schedule = callbacks()
print(model_FC.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1, 7)]            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7)                 0
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               4096
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               262656
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 128)               512
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               16512
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 64)                256
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 64)                256
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                2080
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 32)                128
# _________________________________________________________________
# dense_20 (Dense)             (None, 16)                528
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 16)                64
# _________________________________________________________________
# dense_21 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 536,227
# Trainable params: 532,291
# Non-trainable params: 3,936
# _________________________________________________________________
# None

# %%
history_FC = model_FC.fit(X_train, Y_train_oh, batch_size = 32, epochs = 200, verbose = 1, callbacks=[early_stop, monitor, lr_schedule], validation_data = (X_val, Y_val_oh))
# Out:
# Epoch 1/200
# 661/661 [==============================] - 13s 14ms/step - loss: 1.2658 - accuracy: 0.4468 - f1: 0.3747 - val_loss: 1.0408 - val_accuracy: 0.5592 - val_f1: 0.3863
# Epoch 2/200
# 661/661 [==============================] - 9s 14ms/step - loss: 1.0518 - accuracy: 0.5593 - f1: 0.4903 - val_loss: 0.9447 - val_accuracy: 0.6224 - val_f1: 0.5190
# Epoch 3/200
# 661/661 [==============================] - 9s 14ms/step - loss: 1.0060 - accuracy: 0.5807 - f1: 0.5250 - val_loss: 0.8804 - val_accuracy: 0.6592 - val_f1: 0.5649
# Epoch 4/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.9716 - accuracy: 0.6004 - f1: 0.5505 - val_loss: 0.8789 - val_accuracy: 0.6477 - val_f1: 0.5620
# Epoch 5/200
# 661/661 [==============================] - 9s 13ms/step - loss: 0.9468 - accuracy: 0.6141 - f1: 0.5683 - val_loss: 0.7660 - val_accuracy: 0.7048 - val_f1: 0.6515
# Epoch 6/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.9389 - accuracy: 0.6179 - f1: 0.5792 - val_loss: 0.8729 - val_accuracy: 0.6399 - val_f1: 0.5833
# Epoch 7/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.9345 - accuracy: 0.6181 - f1: 0.5786 - val_loss: 0.7946 - val_accuracy: 0.7084 - val_f1: 0.6349
# Epoch 8/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.9103 - accuracy: 0.6333 - f1: 0.5968 - val_loss: 0.8509 - val_accuracy: 0.6641 - val_f1: 0.6047
# Epoch 9/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.8981 - accuracy: 0.6409 - f1: 0.6067 - val_loss: 0.8129 - val_accuracy: 0.6915 - val_f1: 0.6415
# Epoch 10/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.8955 - accuracy: 0.6359 - f1: 0.6074 - val_loss: 0.7738 - val_accuracy: 0.7073 - val_f1: 0.6463
# Epoch 11/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.8760 - accuracy: 0.6453 - f1: 0.6180 - val_loss: 0.7541 - val_accuracy: 0.7169 - val_f1: 0.6601
# Epoch 12/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.8682 - accuracy: 0.6480 - f1: 0.6206 - val_loss: 0.7955 - val_accuracy: 0.6941 - val_f1: 0.6560
# Epoch 13/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.8608 - accuracy: 0.6552 - f1: 0.6316 - val_loss: 0.8227 - val_accuracy: 0.6520 - val_f1: 0.6090
# Epoch 14/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.8567 - accuracy: 0.6517 - f1: 0.6311 - val_loss: 0.7291 - val_accuracy: 0.7383 - val_f1: 0.6996
# Epoch 15/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.8472 - accuracy: 0.6653 - f1: 0.6413 - val_loss: 0.7529 - val_accuracy: 0.6962 - val_f1: 0.6561
# Epoch 16/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.8335 - accuracy: 0.6734 - f1: 0.6525 - val_loss: 0.7745 - val_accuracy: 0.7062 - val_f1: 0.6581
# Epoch 17/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.8386 - accuracy: 0.6658 - f1: 0.6468 - val_loss: 0.7585 - val_accuracy: 0.7311 - val_f1: 0.6625
# Epoch 18/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.8278 - accuracy: 0.6711 - f1: 0.6552 - val_loss: 0.8293 - val_accuracy: 0.6713 - val_f1: 0.6201
# Epoch 19/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.8285 - accuracy: 0.6700 - f1: 0.6540 - val_loss: 0.7365 - val_accuracy: 0.7296 - val_f1: 0.6740
# Epoch 20/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.8171 - accuracy: 0.6764 - f1: 0.6584 - val_loss: 0.8252 - val_accuracy: 0.6433 - val_f1: 0.6207
# Epoch 21/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7976 - accuracy: 0.6822 - f1: 0.6654 - val_loss: 0.7674 - val_accuracy: 0.6928 - val_f1: 0.6520
# Epoch 22/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.8049 - accuracy: 0.6781 - f1: 0.6649 - val_loss: 0.7836 - val_accuracy: 0.6862 - val_f1: 0.6396
# Epoch 23/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7984 - accuracy: 0.6897 - f1: 0.6741 - val_loss: 0.8315 - val_accuracy: 0.6650 - val_f1: 0.6156
# Epoch 24/200
# 661/661 [==============================] - 10s 14ms/step - loss: 0.8071 - accuracy: 0.6805 - f1: 0.6638 - val_loss: 0.7521 - val_accuracy: 0.7069 - val_f1: 0.6686
# Epoch 25/200
# 661/661 [==============================] - 10s 15ms/step - loss: 0.8037 - accuracy: 0.6772 - f1: 0.6646 - val_loss: 0.7622 - val_accuracy: 0.7052 - val_f1: 0.6594
# Epoch 26/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7897 - accuracy: 0.6891 - f1: 0.6757 - val_loss: 0.7548 - val_accuracy: 0.7075 - val_f1: 0.6656
# Epoch 27/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7850 - accuracy: 0.6926 - f1: 0.6804 - val_loss: 0.8463 - val_accuracy: 0.6222 - val_f1: 0.5812
# Epoch 28/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7736 - accuracy: 0.6969 - f1: 0.6846 - val_loss: 0.7772 - val_accuracy: 0.7075 - val_f1: 0.6756
# Epoch 29/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7785 - accuracy: 0.6870 - f1: 0.6764 - val_loss: 0.7703 - val_accuracy: 0.7013 - val_f1: 0.6745
# Epoch 30/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7714 - accuracy: 0.6986 - f1: 0.6859 - val_loss: 0.7535 - val_accuracy: 0.6762 - val_f1: 0.6581
# Epoch 31/200
# 661/661 [==============================] - 10s 16ms/step - loss: 0.7708 - accuracy: 0.6942 - f1: 0.6863 - val_loss: 0.7974 - val_accuracy: 0.6765 - val_f1: 0.6383
# Epoch 32/200
# 661/661 [==============================] - 10s 15ms/step - loss: 0.7683 - accuracy: 0.6978 - f1: 0.6866 - val_loss: 0.8732 - val_accuracy: 0.5867 - val_f1: 0.5592
# Epoch 33/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7591 - accuracy: 0.6994 - f1: 0.6876 - val_loss: 0.7689 - val_accuracy: 0.6786 - val_f1: 0.6365
# Epoch 34/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7546 - accuracy: 0.7083 - f1: 0.6987 - val_loss: 0.7315 - val_accuracy: 0.7284 - val_f1: 0.7093
# Epoch 35/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7475 - accuracy: 0.7085 - f1: 0.6973 - val_loss: 0.7514 - val_accuracy: 0.7007 - val_f1: 0.6698
# Epoch 36/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7540 - accuracy: 0.7113 - f1: 0.7000 - val_loss: 0.8229 - val_accuracy: 0.6596 - val_f1: 0.6401
# Epoch 37/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7341 - accuracy: 0.7199 - f1: 0.7118 - val_loss: 0.7647 - val_accuracy: 0.6988 - val_f1: 0.6750
# Epoch 38/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7460 - accuracy: 0.7172 - f1: 0.7038 - val_loss: 0.7167 - val_accuracy: 0.7166 - val_f1: 0.6804
# Epoch 39/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7339 - accuracy: 0.7181 - f1: 0.7070 - val_loss: 0.8292 - val_accuracy: 0.6658 - val_f1: 0.6423
# Epoch 40/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7362 - accuracy: 0.7161 - f1: 0.7075 - val_loss: 0.7640 - val_accuracy: 0.6822 - val_f1: 0.6535
# Epoch 41/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7146 - accuracy: 0.7277 - f1: 0.7204 - val_loss: 0.8312 - val_accuracy: 0.6443 - val_f1: 0.6247
# Epoch 42/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7094 - accuracy: 0.7331 - f1: 0.7262 - val_loss: 0.8047 - val_accuracy: 0.6777 - val_f1: 0.6536
# Epoch 43/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7171 - accuracy: 0.7245 - f1: 0.7170 - val_loss: 0.7856 - val_accuracy: 0.6809 - val_f1: 0.6553
# Epoch 44/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7029 - accuracy: 0.7328 - f1: 0.7259 - val_loss: 0.8037 - val_accuracy: 0.6541 - val_f1: 0.6407
# Epoch 45/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7057 - accuracy: 0.7336 - f1: 0.7261 - val_loss: 0.7770 - val_accuracy: 0.7035 - val_f1: 0.6749
# Epoch 46/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.7093 - accuracy: 0.7275 - f1: 0.7211 - val_loss: 0.7712 - val_accuracy: 0.6864 - val_f1: 0.6598
# Epoch 47/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.6983 - accuracy: 0.7325 - f1: 0.7240 - val_loss: 0.8281 - val_accuracy: 0.6807 - val_f1: 0.6636
# Epoch 48/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.6932 - accuracy: 0.7377 - f1: 0.7303 - val_loss: 0.8496 - val_accuracy: 0.6903 - val_f1: 0.6720
# Epoch 49/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0
200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.6821 - accuracy: 0.7441 - f1: 0.7390 - val_loss: 0.7936 - val_accuracy: 0.7033 - val_f1: 0.6960
# Epoch 70/200
# 661/661 [==============================] - 10s 14ms/step - loss: 0.6710 - accuracy: 0.7501 - f1: 0.7432 - val_loss: 0.7965 - val_accuracy: 0.6830 - val_f1: 0.6759
# Epoch 71/200
# 661/661 [==============================] - 10s 15ms/step - loss: 0.6714 - accuracy: 0.7489 - f1: 0.7450 - val_loss: 0.8191 - val_accuracy: 0.6682 - val_f1: 0.6585
# Epoch 72/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.6700 - accuracy: 0.7465 - f1: 0.7412 - val_loss: 0.8299 - val_accuracy: 0.6414 - val_f1: 0.6342
# Epoch 73/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.6672 - accuracy: 0.7470 - f1: 0.7420 - val_loss: 0.8238 - val_accuracy: 0.6733 - val_f1: 0.6632
# Epoch 74/200
# 661/661 [==============================] - 10s 14ms/step - loss: 0.6668 - accuracy: 0.7521 - f1: 0.7463 - val_loss: 0.7932 - val_accuracy: 0.6788 - val_f1: 0.6662
# Epoch 75/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.6667 - accuracy: 0.7487 - f1: 0.7432 - val_loss: 0.8334 - val_accuracy: 0.6786 - val_f1: 0.6674
# Epoch 76/200
# 661/661 [==============================] - 10s 14ms/step - loss: 0.6589 - accuracy: 0.7499 - f1: 0.7444 - val_loss: 0.8568 - val_accuracy: 0.6556 - val_f1: 0.6496
# Epoch 77/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.6571 - accuracy: 0.7610 - f1: 0.7555 - val_loss: 0.7715 - val_accuracy: 0.6954 - val_f1: 0.6838
# Epoch 78/200
# 661/661 [==============================] - 9s 14ms/step - loss: 0.6551 - accuracy: 0.7549 - f1: 0.7490 - val_loss: 0.8279 - val_accuracy: 0.6852 - val_f1: 0.6786

# %%
model_FC.load_weights(model_name_fcn)
loss_FC = model_FC.evaluate(X_test, Y_test_oh, verbose=0)
print('Final loss (cross-entropy and accuracy, F1):',loss_FC)

plt.plot(history_FC.history['loss'], label = "Train loss")
plt.plot(history_FC.history['val_loss'], label = "Val loss")
plt.xlabel("Epoch (iteration)")
plt.ylabel("Loss")
plt.legend()
plt.grid()
plt.show()


plt.plot(history_FC.history['accuracy'], label = "Train accuarcy")
plt.plot(history_FC.history['val_accuracy'], label = "Val accuarcy")
plt.xlabel("Epoch (iteration)")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()
plt.show()


plt.plot(history_FC.history['f1'], label = "Train F1")
plt.plot(history_FC.history['val_f1'], label = "Val F1")
plt.xlabel("Epoch (iteration)")
plt.ylabel("F1")
plt.legend()
plt.grid()
plt.show()
# Out:
# Final loss (cross-entropy and accuracy, F1): [1.397464632987976, 0.5043056011199951, 0.48356032371520996]

# %%
shape = 40
X_train, Y_train, X_val, Y_val, X_test, Y_test = get_dataset(data_folder, shape= shape)
X_train, X_val, X_test = normalization(X_train, X_val, X_test)
Y_train_oh, Y_val_oh, Y_test_oh = oneHotEndcoding(Y_train, Y_val, Y_test)
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (551, 40, 7)
# (148, 40, 7)
# (56, 40, 7)

# %%
model_FC = my_model_fully_connected(ishape=(len(X_train[0]), len(X_train[0,0])))
early_stop, monitor, lr_schedule = callbacks()
print(model_FC.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 40, 7)]           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 280)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 30)                8430
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30)                120
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 30)                930
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 30)                120
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 30)                930
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 30)                120
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 30)                930
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 30)                120
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 62
# =================================================================
# Total params: 11,762
# Trainable params: 11,522
# Non-trainable params: 240
# _________________________________________________________________
# None

# %%
history_FC = model_FC.fit(X_train, Y_train_oh, batch_size = 32, epochs = 200, verbose = 1, callbacks=[early_stop, monitor, lr_schedule], validation_data = (X_val, Y_val_oh))
# Out:
# Epoch 1/200
# 18/18 [==============================] - 2s 22ms/step - loss: 1.3065 - accuracy: 0.4640 - val_loss: 2.2022 - val_accuracy: 0.4107
# Epoch 2/200
# 18/18 [==============================] - 0s 6ms/step - loss: 1.2429 - accuracy: 0.4823 - val_loss: 1.5874 - val_accuracy: 0.4107
# Epoch 3/200
# 18/18 [==============================] - 0s 7ms/step - loss: 1.2359 - accuracy: 0.5065 - val_loss: 1.3596 - val_accuracy: 0.4107
# Epoch 4/200
# 18/18 [==============================] - 0s 6ms/step - loss: 1.1913 - accuracy: 0.5005 - val_loss: 1.2151 - val_accuracy: 0.4107
# Epoch 5/200
# 18/18 [==============================] - 0s 5ms/step - loss: 1.2244 - accuracy: 0.4824 - val_loss: 1.1387 - val_accuracy: 0.4107
# Epoch 6/200
# 18/18 [==============================] - 0s 4ms/step - loss: 1.2677 - accuracy: 0.4626 - val_loss: 1.0539 - val_accuracy: 0.4107
# Epoch 7/200
# 18/18 [==============================] - 0s 5ms/step - loss: 1.2536 - accuracy: 0.4698 - val_loss: 1.0376 - val_accuracy: 0.4107
# Epoch 8/200
# 18/18 [==============================] - 0s 5ms/step - loss: 1.2853 - accuracy: 0.4980 - val_loss: 1.1054 - val_accuracy: 0.4107
# Epoch 9/200
# 18/18 [==============================] - 0s 4ms/step - loss: 1.2721 - accuracy: 0.4764 - val_loss: 1.1684 - val_accuracy: 0.4107
# Epoch 10/200
# 18/18 [==============================] - 0s 4ms/step - loss: 1.1916 - accuracy: 0.5100 - val_loss: 1.1496 - val_accuracy: 0.4107
# Epoch 11/200
# 18/18 [==============================] - 0s 4ms/step - loss: 1.1898 - accuracy: 0.5109 - val_loss: 1.1416 - val_accuracy: 0.4286
# Epoch 12/200
# 18/18 [==============================] - 0s 6ms/step - loss: 1.2054 - accuracy: 0.4984 - val_loss: 1.0934 - val_accuracy: 0.4107
# Epoch 13/200
# 18/18 [==============================] - 0s 5ms/step - loss: 1.3067 - accuracy: 0.4686 - val_loss: 1.0724 - val_accuracy: 0.3750
# Epoch 14/200
# 18/18 [==============================] - 0s 4ms/step - loss: 1.2001 - accuracy: 0.5126 - val_loss: 1.0709 - val_accuracy: 0.3393
# Epoch 15/200
# 18/18 [==============================] - 0s 7ms/step - loss: 1.0426 - accuracy: 0.5453 - val_loss: 1.0705 - val_accuracy: 0.3393
# Epoch 16/200
# 18/18 [==============================] - 0s 6ms/step - loss: 1.0552 - accuracy: 0.5037 - val_loss: 1.0596 - val_accuracy: 0.3393
# Epoch 17/200
# 18/18 [==============================] - 0s 6ms/step - loss: 1.0868 - accuracy: 0.5081 - val_loss: 1.0404 - val_accuracy: 0.3750
# 18/18 [==============================] - 0s 7ms/step - loss: 1.1596 - accuracy: 0.5123 - val_loss: 0.9074 - val_accuracy: 0.5893
# Epoch 58/200
# 18/18 [==============================] - 0s 6ms/step - loss: 1.0117 - accuracy: 0.5324 - val_loss: 0.9031 - val_accuracy: 0.5536
# Epoch 59/200
# 18/18 [==============================] - 0s 4ms/step - loss: 1.1349 - accuracy: 0.5135 - val_loss: 0.9053 - val_accuracy: 0.5357
# Epoch 60/200
# 18/18 [==============================] - 0s 4ms/step - loss: 1.0908 - accuracy: 0.4816 - val_loss: 0.9072 - val_accuracy: 0.5357
# Epoch 61/200
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0320 - accuracy: 0.5251 - val_loss: 0.9081 - val_accuracy: 0.5357
# Epoch 62/200
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0393 - accuracy: 0.5271 - val_loss: 0.9074 - val_accuracy: 0.5357
# Epoch 63/200
# 18/18 [==============================] - 0s 5ms/step - loss: 1.1807 - accuracy: 0.4684 - val_loss: 0.9075 - val_accuracy: 0.5536
# Epoch 64/200
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0093 - accuracy: 0.5320 - val_loss: 0.9055 - val_accuracy: 0.5536
# Epoch 65/200
# 18/18 [==============================] - 0s 5ms/step - loss: 1.1575 - accuracy: 0.4509 - val_loss: 0.8992 - val_accuracy: 0.5357
# Epoch 66/200
# 18/18 [==============================] - 0s 6ms/step - loss: 1.1422 - accuracy: 0.5019 - val_loss: 0.9029 - val_accuracy: 0.5357
# Epoch 67/200
# 18/18 [==============================] - 0s 5ms/step - loss: 1.1239 - accuracy: 0.4793 - val_loss: 0.9031 - val_accuracy: 0.5357
# Epoch 68/200
# 18/18 [==============================] - 0s 4ms/step - loss: 1.0239 - accuracy: 0.5694 - val_loss: 0.9050 - val_accuracy: 0.5357
# Epoch 69/200
# 18/18 [==============================] - 0s 5ms/step - loss: 1.0731 - accuracy: 0.4990 - val_loss: 0.9011 - val_accuracy: 0.4821
# Epoch 70/200
# 18/18 [==============================] - 0s 4ms/step - loss: 1.0073 - accuracy: 0.5092 - val_loss: 0.9015 - val_accuracy: 0.5357
# Epoch 71/200
# 18/18 [==============================] - 0s 4ms/step - loss: 1.1108 - accuracy: 0.5030 - val_loss: 0.9024 - val_accuracy: 0.5179
# Epoch 72/200
# 18/18 [==============================] - 0s 5ms/step - loss: 1.1542 - accuracy: 0.4720 - val_loss: 0.8997 - val_accuracy: 0.5000

# %%
model_FC.load_weights(model_name_fcn)
loss_FC = model_FC.evaluate(X_test, Y_test_oh, verbose=0)
print('Final loss (cross-entropy and accuracy):',loss_FC)

plt.plot(history_FC.history['loss'], label = "Train loss")
plt.plot(history_FC.history['val_loss'], label = "Val loss")
plt.xlabel("Epoch (iteration)")
plt.ylabel("Loss")
plt.legend()
plt.grid()
plt.show()


plt.plot(history_FC.history['accuracy'], label = "Train accuarcy")
plt.plot(history_FC.history['val_accuracy'], label = "Val accuarcy")
plt.xlabel("Epoch (iteration)")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()
plt.show()
# Out:
# Final loss (cross-entropy and accuracy): [0.8897145986557007, 0.5337837934494019]
