# %%
import numpy as np
import tensorflow as tf
from google.colab import drive
import os
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from sklearn import preprocessing
import random

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_folder = '/content/drive/MyDrive/Colab Notebooks/UAH-DRIVESET-v1'
shape = 40

# %%
def get_dataset(data_path, train_per = 0.70, val_per = 0.1, test_per = 0.2):
    # initialize data variable as list
    X_train, Y_train, X_val, Y_val, X_test, Y_test = [], [], [], [], [], []

    for root, dirs, files in os.walk(data_path, topdown=False):
        if len(files) < 2:
            continue
        else:
            gps_df = get_data_list(root)
            random.shuffle(gps_df)

            train_split_index = int(train_per * len(gps_df))
            val_split_index = int(val_per * len(gps_df)) + train_split_index

            X_train.extend(gps_df[: train_split_index])
            for i in range(train_split_index):
              Y_train.append([root.split("/")[-1].split("-")[2], get_trip_labels(root), get_road_type(root)])

            X_val.extend(gps_df[train_split_index:val_split_index])
            for i in range(train_split_index, val_split_index):
              Y_val.append([root.split("/")[-1].split("-")[2], get_trip_labels(root), get_road_type(root)])

            X_test.extend(gps_df[val_split_index:])
            for i in range(val_split_index, len(gps_df)):
              Y_test.append([root.split("/")[-1].split("-")[2], get_trip_labels(root), get_road_type(root)])

    labels_columns = ["driver", "type", "road"]
    Y_train = pd.DataFrame(data= np.array(Y_train), columns=labels_columns)
    Y_val = pd.DataFrame(data= np.array(Y_val), columns=labels_columns)
    Y_test = pd.DataFrame(data= np.array(Y_test), columns=labels_columns)
    X_train = np.array(X_train)
    X_val = np.array(X_val)
    X_test = np.array(X_test)
    return X_train, Y_train, X_val, Y_val, X_test, Y_test


def get_data_list(root, shape=shape):
    data_list = []
    gps_df = import_uah_trip_data(root)
    # df.latitude.diff().shift(-1)

    # print(gps_df["driver"])
    gps_df["delta_latitude"] = gps_df.latitude.diff()
    gps_df["delta_longitude"] = gps_df.longitude.diff()
    gps_df["delta_altitude"] = gps_df.altitude.diff()
    gps_df["delta_latitude"][0] = 0
    gps_df["delta_longitude"][0] = 0
    gps_df["delta_altitude"][0] = 0
    # gps_df["driver"] = int((root.split("/")[-1].split("-")[2]).replace("D",""))
    gps_df["road_type"] = get_road_type(root)
    # gps_df = gps_df.drop(columns=['longitude', 'latitude', 'altitude'])
    divisions = int(len(gps_df)/shape)
    gps_df = gps_df[:divisions * shape]
    for i in range(divisions):
      data_list.append(gps_df[shape * (i):shape * (i+1)])
    return data_list

def import_uah_trip_data(root_path):
    # import raw inertial data
    gps_file_path = os.path.join(root_path, "RAW_GPS.txt")
    gps_df = pd.read_csv(gps_file_path, sep=" ", header=None).iloc[:, 0:7]
    # add the column names
    gps_df.columns = [
        "timestamp",
        "speed",
        "latitude",
        "longitude",
        "altitude",
        "verticalAccuracy",
        "horizentalAccuracy",
    ]
    
    dataFrame = pd.DataFrame(data=gps_df, columns=gps_df.columns)
 
    return dataFrame

def get_trip_labels(file_path):
    if "NORMAL" in file_path:
        label = "NORMAL"
    elif "AGGRESSIVE" in file_path:
        label = "AGGRESSIVE"
    elif "DROWSY" in file_path:
        label = "DROWSY"
    else:
        label = None
    return label


def get_road_type(file_path):
    if "SECONDARY" in file_path:
        return 1
    elif "MOTORWAY" in file_path:
        return 2
    else:
        return None

# %%
X_train, Y_train, X_val, Y_val, X_test, Y_test = get_dataset(data_folder)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(X_train.shape)

print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
print(X_val.shape)
print(Y_val.shape)
# Out:
# (510, 40, 11)
# (510, 3)
# (189, 40, 11)
# (189, 3)
# (56, 40, 11)
# (56, 3)

# %%
X_train[:]
# Out:
# array([[[ 9.6530000e+01,  1.0970000e+02,  4.0533073e+01, ...,
#          -3.1900000e-04,  1.5000000e+00,  1.0000000e+00],
#         [ 9.7530000e+01,  1.0970000e+02,  4.0533073e+01, ...,
#           0.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         [ 9.8550000e+01,  1.1170000e+02,  4.0533295e+01, ...,
#          -6.7000000e-04,  2.7000000e+00,  1.0000000e+00],
#         ...,
#         [ 1.3351000e+02,  1.1130000e+02,  4.0533817e+01, ...,
#          -3.7000000e-04,  5.0000000e-01,  1.0000000e+00],
#         [ 1.3456000e+02,  1.1050000e+02,  4.0533813e+01, ...,
#          -3.6500000e-04, -9.0000000e-01,  1.0000000e+00],
#         [ 1.3548000e+02,  1.1050000e+02,  4.0533813e+01, ...,
#           0.0000000e+00,  0.0000000e+00,  1.0000000e+00]],
#
#        [[ 4.1657000e+02,  8.7800000e+01,  4.0556759e+01, ...,
#          -2.9200000e-04, -1.4000000e+00,  1.0000000e+00],
#         [ 4.1751000e+02,  8.8500000e+01,  4.0556763e+01, ...,
#          -2.9100000e-04, -6.0000000e-01,  1.0000000e+00],
#         [ 4.1851000e+02,  8.9800000e+01,  4.0556778e+01, ...,
#          -2.9500000e-04, -1.3000000e+00,  1.0000000e+00],
#         ...,
#         [ 4.5362000e+02,  8.9800000e+01,  4.0561867e+01, ...,
#          -4.9000000e-05, -1.0000000e+00,  1.0000000e+00],
#         [ 4.5449000e+02,  8.9800000e+01,  4.0562080e+01, ...,
#          -3.8000000e-05, -5.0000000e-01,  1.0000000e+00],
#         [ 4.5552000e+02,  8.9200000e+01,  4.0562302e+01, ...,
#          -3.4000000e-05, -9.0000000e-01,  1.0000000e+00]],
#
#        [[ 5.6550000e+01,  1.0490000e+02,  4.0525410e+01, ...,
#          -3.3200000e-04, -1.0000000e+00,  1.0000000e+00],
#         [ 5.7530000e+01,  1.0420000e+02,  4.0525501e+01, ...,
#          -3.1800000e-04, -1.2000000e+00,  1.0000000e+00],
#         [ 5.8490000e+01,  1.0460000e+02,  4.0525604e+01, ...,
#          -3.0400000e-04, -9.0000000e-01,  1.0000000e+00],
#         ...,
#         [ 9.3500000e+01,  1.0820000e+02,  4.0532696e+01, ...,
#          -6.1200000e-04,  1.3000000e+00,  1.0000000e+00],
#         [ 9.4480000e+01,  1.0620000e+02,  4.0532833e+01, ...,
#          -3.0300000e-04,  7.0000000e-01,  1.0000000e+00],
#         [ 9.5500000e+01,  1.0510000e+02,  4.0532959e+01, ...,
#          -3.0300000e-04,  1.2000000e+00,  1.0000000e+00]],
#
#        ...,
#
#        [[ 6.9008000e+02,  1.1180000e+02,  4.0471672e+01, ...,
#           3.4200000e-04, -1.4000000e+00,  2.0000000e+00],
#         [ 6.9107000e+02,  1.1070000e+02,  4.0471764e+01, ...,
#           3.4700000e-04, -6.0000000e-01,  2.0000000e+00],
#         [ 6.9207000e+02,  1.1130000e+02,  4.0471859e+01, ...,
#           3.4100000e-04, -4.0000000e-01,  2.0000000e+00],
#         ...,
#         [ 7.2707000e+02,  1.2280000e+02,  4.0475601e+01, ...,
#           3.5800000e-04, -2.1000000e+00,  2.0000000e+00],
#         [ 7.2807000e+02,  1.2240000e+02,  4.0475777e+01, ...,
#           3.2000000e-04,  7.0000000e-01,  2.0000000e+00],
#         [ 7.2912000e+02,  1.2160000e+02,  4.0475960e+01, ...,
#           3.3500000e-04, -6.0000000e-01,  2.0000000e+00]],
#
#        [[ 3.7007000e+02,  1.1070000e+02,  4.0466785e+01, ...,
#          -3.6500000e-04,  1.0000000e+00,  2.0000000e+00],
#         [ 3.7110000e+02,  1.1070000e+02,  4.0466789e+01, ...,
#          -3.6000000e-04, -1.0000000e-01,  2.0000000e+00],
#         [ 3.7210000e+02,  1.1120000e+02,  4.0466805e+01, ...,
#          -3.6200000e-04, -4.0000000e-01,  2.0000000e+00],
#         ...,
#         [ 4.0712000e+02,  8.8300000e+01,  4.0467224e+01, ...,
#          -2.9500000e-04, -1.0000000e-01,  2.0000000e+00],
#         [ 4.0807000e+02,  8.8200000e+01,  4.0467213e+01, ...,
#          -2.9200000e-04,  3.0000000e-01,  2.0000000e+00],
#         [ 4.0906000e+02,  8.9200000e+01,  4.0467209e+01, ...,
#          -2.9500000e-04,  4.0000000e-01,  2.0000000e+00]],
#
#        [[ 1.7005000e+02,  1.0520000e+02,  4.0486679e+01, ...,
#          -2.4000000e-04,  1.0000000e-01,  2.0000000e+00],
#         [ 1.7113000e+02,  1.0510000e+02,  4.0486496e+01, ...,
#          -2.4100000e-04, -1.0000000e-01,  2.0000000e+00],
#         [ 1.7211000e+02,  1.0320000e+02,  4.0486309e+01, ...,
#          -2.3500000e-04,  2.0000000e-01,  2.0000000e+00],
#         ...,
#         [ 2.0710000e+02,  9.4500000e+01,  4.0479412e+01, ...,
#          -1.8600000e-04, -1.0000000e-01,  2.0000000e+00],
#         [ 2.0809000e+02,  9.2800000e+01,  4.0479240e+01, ...,
#          -1.9500000e-04, -3.0000000e-01,  2.0000000e+00],
#         [ 2.0916000e+02,  9.3300000e+01,  4.0479065e+01, ...,
#          -1.9000000e-04, -6.0000000e-01,  2.0000000e+00]]])

# %%
Y_val
# Out:
#    driver        type road
# 0      D2  AGGRESSIVE    1
# 1      D2      DROWSY    2
# 2      D2      DROWSY    2
# 3      D2  AGGRESSIVE    2
# 4      D2  AGGRESSIVE    2
# 5      D2      DROWSY    1
# 6      D2      NORMAL    1
# 7      D2      NORMAL    1
# 8      D2      NORMAL    2
# 9      D2      NORMAL    2
# 10     D5  AGGRESSIVE    2
# 11     D5      NORMAL    1
# 12     D5      DROWSY    2
# 13     D5      DROWSY    2
# 14     D5      NORMAL    1
# 15     D5      DROWSY    1
# 16     D5  AGGRESSIVE    1
# 17     D5      NORMAL    2
# 18     D5      NORMAL    2
# 19     D3  AGGRESSIVE    1
# 20     D3      DROWSY    2
# 21     D3      DROWSY    2
# 22     D3      DROWSY    1
# 23     D3      NORMAL    1
# 24     D3      NORMAL    1
# 25     D3      NORMAL    2
# 26     D3      NORMAL    2
# 27     D3  AGGRESSIVE    2
# 28     D3  AGGRESSIVE    2
# 29     D4  AGGRESSIVE    2
# 30     D4  AGGRESSIVE    2
# 31     D4      NORMAL    1
# 32     D4      NORMAL    1
# 33     D4      NORMAL    2
# 34     D4      NORMAL    2
# 35     D4  AGGRESSIVE    1
# 36     D4      DROWSY    1
# 37     D4      DROWSY    2
# 38     D4      DROWSY    2
# 39     D1      NORMAL    1
# 40     D1      DROWSY    2
# 41     D1      DROWSY    2
# 42     D1      DROWSY    1
# 43     D1      NORMAL    2
# 44     D1      NORMAL    2
# 45     D1      NORMAL    1
# 46     D1  AGGRESSIVE    2
# 47     D1  AGGRESSIVE    1
# 48     D6      NORMAL    1
# 49     D6      NORMAL    2
# 50     D6      NORMAL    2
# 51     D6      DROWSY    1
# 52     D6      DROWSY    2
# 53     D6      DROWSY    2
# 54     D6  AGGRESSIVE    2
# 55     D6  AGGRESSIVE    2

# %%
type = 0

if type == 0:
    for i in range(len(X_train[0,0])):
        train_min, train_max = X_train[:,0,i].min(),X_train[:,0,i].max() 
        X_train[:,0,i] = (X_train[:,0,i] - train_min)/(train_max - train_min)
        X_val[:,0,i] = (X_val[:,0,i] - train_min)/(train_max - train_min)
        X_test[:,0,i] = (X_test[:,0,i] - train_min)/(train_max - train_min)
elif type == 1:
    for i in range(len(X_train[0,0])):
        train_mean, train_std = X_train[:,0,i].mean(),X_train[:,0,i].std() 
        X_train[:,0,i] = (X_train[:,0,i] - train_mean)/train_std
        X_val[:,0,i] = (X_val[:,0,i] - train_mean)/train_std
        X_test[:,0,i] = (X_test[:,0,i] - train_mean)/train_std

# %%
Y_train_oh = pd.get_dummies(Y_train.type, prefix='type')
Y_val_oh = pd.get_dummies(Y_val.type, prefix='type')
Y_test_oh = pd.get_dummies(Y_test.type, prefix='type')
Y_train_oh
# Out:
#      type_AGGRESSIVE  type_DROWSY  type_NORMAL
# 0                  1            0            0
# 1                  1            0            0
# 2                  1            0            0
# 3                  1            0            0
# 4                  1            0            0
# ..               ...          ...          ...
# 505                1            0            0
# 506                1            0            0
# 507                1            0            0
# 508                1            0            0
# 509                1            0            0
#
# [510 rows x 3 columns]

# %%
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
        possible_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
        predicted_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+tf.keras.backend.epsilon()))

# %%
def my_model_fully_connected(k = 3, lr = 1e-4, ishape = (shape,11), drop_out = 0.1, weight_decay = 1e-4):
    model_input = tf.keras.layers.Input(shape=ishape)
    model_input_flatten = tf.keras.layers.Flatten()(model_input)


    # l0 = tf.keras.layers.Dense(1024, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(model_input_flatten)
    # l0_Batch = tf.keras.layers.BatchNormalization()(l0)


    l1 = tf.keras.layers.Dense(512, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(model_input_flatten)
    l1_Batch = tf.keras.layers.BatchNormalization()(l1)
    # l1_dropOut = tf.keras.layers.Dropout(drop_out)(l1_Batch)

    l2 = tf.keras.layers.Dense(512, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l1_Batch)
    l2_Batch = tf.keras.layers.BatchNormalization()(l2)
    # l2_dropOut = tf.keras.layers.Dropout(2*drop_out)(l2_Batch)

    l3 = tf.keras.layers.Dense(256, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l2_Batch)
    l3_Batch = tf.keras.layers.BatchNormalization()(l3)
    # l3_dropOut = tf.keras.layers.Dropout(3*drop_out)(l3_Batch)

    l4 = tf.keras.layers.Dense(256, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l3_Batch)
    l4_Batch = tf.keras.layers.BatchNormalization()(l4)
    # l4_dropOut = tf.keras.layers.Dropout(4*drop_out)(l4_Batch)

    l5 = tf.keras.layers.Dense(128, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l4_Batch)
    l5_Batch = tf.keras.layers.BatchNormalization()(l5)
    # l5_dropOut = tf.keras.layers.Dropout(5*drop_out)(l5_Batch)

    l6 = tf.keras.layers.Dense(128, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l5_Batch)
    l6_Batch = tf.keras.layers.BatchNormalization()(l6)
    # l6_dropOut = tf.keras.layers.Dropout(5*drop_out)(l6_Batch)

    l7 = tf.keras.layers.Dense(64, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l6_Batch)
    l7_Batch = tf.keras.layers.BatchNormalization()(l7)
    # l7_dropOut = tf.keras.layers.Dropout(3*drop_out)(l7_Batch)

    l8 = tf.keras.layers.Dense(64, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l7_Batch)
    l8_Batch = tf.keras.layers.BatchNormalization()(l8)
    # l8_dropOut = tf.keras.layers.Dropout(5*drop_out)(l8_Batch)

    l9 = tf.keras.layers.Dense(32, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l8_Batch)
    l9_Batch = tf.keras.layers.BatchNormalization()(l9)
    # l9_dropOut = tf.keras.layers.Dropout(5*drop_out)(l9_Batch)

    l10 = tf.keras.layers.Dense(16, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.L2(weight_decay))(l9_Batch)
    l10_Batch = tf.keras.layers.BatchNormalization()(l10)
    
    
    out = tf.keras.layers.Dense(k,activation = 'softmax')(l10_Batch)
    model = tf.keras.models.Model(inputs = model_input, outputs = out)
    opt_rms = tf.keras.optimizers.RMSprop(lr=lr,decay=1e-6)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss='categorical_crossentropy', metrics = ["accuracy", f1])
    return model

# %%
model_FC = my_model_fully_connected()
print(model_FC.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 40, 11)]          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 440)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               225792
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_23 (Dense)             (None, 512)               262656
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_24 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_25 (Dense)             (None, 256)               65792
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_26 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 128)               512
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               16512
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 128)               512
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 64)                256
# _________________________________________________________________
# dense_29 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 64)                256
# _________________________________________________________________
# dense_30 (Dense)             (None, 32)                2080
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 32)                128
# _________________________________________________________________
# dense_31 (Dense)             (None, 16)                528
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 16)                64
# _________________________________________________________________
# dense_32 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 757,923
# Trainable params: 753,987
# Non-trainable params: 3,936
# _________________________________________________________________
# None

# %%
model_name_fcn = "team_4_FCN.h5"

early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 40)

monitor = tf.keras.callbacks.ModelCheckpoint(model_name_fcn, monitor='val_loss',\
                                             verbose=0,save_best_only=True,\
                                             save_weights_only=True,\
                                             mode='min')
# Learning rate schedule
def scheduler(epoch, lr):
    if epoch%60 == 0:
        lr = lr/2
    return lr

lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler,verbose = 0)

# %%
history_FC = model_FC.fit(X_train, Y_train_oh, batch_size = 32, epochs = 220, verbose = 1, callbacks=[early_stop, monitor, lr_schedule], validation_data = (X_val, Y_val_oh))
# Out:
# Epoch 1/220
# 16/16 [==============================] - 4s 48ms/step - loss: 1.6935 - accuracy: 0.3571 - f1: 0.3093 - val_loss: 1.3553 - val_accuracy: 0.4107 - val_f1: 0.4115
# Epoch 2/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.3397 - accuracy: 0.4464 - f1: 0.3614 - val_loss: 1.3395 - val_accuracy: 0.4107 - val_f1: 0.4115
# Epoch 3/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.2477 - accuracy: 0.4974 - f1: 0.3982 - val_loss: 1.3264 - val_accuracy: 0.4107 - val_f1: 0.4115
# Epoch 4/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.2283 - accuracy: 0.4936 - f1: 0.3931 - val_loss: 1.3156 - val_accuracy: 0.4107 - val_f1: 0.4115
# Epoch 5/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.2540 - accuracy: 0.4394 - f1: 0.3146 - val_loss: 1.3061 - val_accuracy: 0.4107 - val_f1: 0.4115
# Epoch 6/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.1994 - accuracy: 0.4867 - f1: 0.3793 - val_loss: 1.2984 - val_accuracy: 0.4107 - val_f1: 0.4115
# Epoch 7/220
# 16/16 [==============================] - 0s 19ms/step - loss: 1.1828 - accuracy: 0.4977 - f1: 0.3980 - val_loss: 1.2920 - val_accuracy: 0.4107 - val_f1: 0.0000e+00
# Epoch 8/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1663 - accuracy: 0.5191 - f1: 0.3937 - val_loss: 1.2867 - val_accuracy: 0.4107 - val_f1: 0.0000e+00
# Epoch 9/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1705 - accuracy: 0.4739 - f1: 0.3643 - val_loss: 1.2826 - val_accuracy: 0.4107 - val_f1: 0.0000e+00
# Epoch 10/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.2067 - accuracy: 0.4394 - f1: 0.3559 - val_loss: 1.2792 - val_accuracy: 0.4107 - val_f1: 0.0000e+00
# Epoch 11/220
# 16/16 [==============================] - 0s 16ms/step - loss: 1.1521 - accuracy: 0.5049 - f1: 0.4102 - val_loss: 1.2765 - val_accuracy: 0.4107 - val_f1: 0.0000e+00
# Epoch 12/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1680 - accuracy: 0.5280 - f1: 0.3750 - val_loss: 1.2741 - val_accuracy: 0.4107 - val_f1: 0.0000e+00
# Epoch 13/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1448 - accuracy: 0.5186 - f1: 0.4007 - val_loss: 1.2715 - val_accuracy: 0.4107 - val_f1: 0.0000e+00
# Epoch 14/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1664 - accuracy: 0.5047 - f1: 0.3611 - val_loss: 1.2692 - val_accuracy: 0.4107 - val_f1: 0.0000e+00
# Epoch 15/220
# 16/16 [==============================] - 0s 16ms/step - loss: 1.1546 - accuracy: 0.5070 - f1: 0.4002 - val_loss: 1.2649 - val_accuracy: 0.4107 - val_f1: 0.0000e+00
# Epoch 16/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.2364 - accuracy: 0.4535 - f1: 0.2743 - val_loss: 1.2628 - val_accuracy: 0.4107 - val_f1: 0.0000e+00
# Epoch 17/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1424 - accuracy: 0.4961 - f1: 0.4183 - val_loss: 1.2594 - val_accuracy: 0.4286 - val_f1: 0.0000e+00
# Epoch 18/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1691 - accuracy: 0.4844 - f1: 0.3512 - val_loss: 1.2496 - val_accuracy: 0.4286 - val_f1: 0.0000e+00
# Epoch 19/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1530 - accuracy: 0.5065 - f1: 0.3572 - val_loss: 1.2504 - val_accuracy: 0.4286 - val_f1: 0.0000e+00
# Epoch 20/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.1341 - accuracy: 0.5522 - f1: 0.3792 - val_loss: 1.2491 - val_accuracy: 0.4464 - val_f1: 0.0303
# Epoch 21/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1428 - accuracy: 0.5035 - f1: 0.3671 - val_loss: 1.2437 - val_accuracy: 0.4107 - val_f1: 0.0303
# Epoch 22/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1487 - accuracy: 0.5280 - f1: 0.3648 - val_loss: 1.2492 - val_accuracy: 0.3214 - val_f1: 0.0303
# Epoch 23/220
# 16/16 [==============================] - 0s 16ms/step - loss: 1.1252 - accuracy: 0.5570 - f1: 0.3969 - val_loss: 1.2621 - val_accuracy: 0.3750 - val_f1: 0.0588
# Epoch 24/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.1280 - accuracy: 0.5259 - f1: 0.4167 - val_loss: 1.2685 - val_accuracy: 0.4464 - val_f1: 0.1924
# Epoch 25/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1148 - accuracy: 0.5211 - f1: 0.3928 - val_loss: 1.2617 - val_accuracy: 0.4286 - val_f1: 0.1782
# Epoch 26/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0982 - accuracy: 0.5354 - f1: 0.4155 - val_loss: 1.2559 - val_accuracy: 0.5000 - val_f1: 0.1952
# Epoch 27/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1259 - accuracy: 0.5122 - f1: 0.3982 - val_loss: 1.2690 - val_accuracy: 0.4107 - val_f1: 0.1826
# Epoch 28/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0836 - accuracy: 0.5624 - f1: 0.4424 - val_loss: 1.2519 - val_accuracy: 0.3571 - val_f1: 0.2111
# Epoch 29/220
# 16/16 [==============================] - 0s 16ms/step - loss: 1.1292 - accuracy: 0.5066 - f1: 0.3680 - val_loss: 1.2612 - val_accuracy: 0.4107 - val_f1: 0.1926
# Epoch 30/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0913 - accuracy: 0.5104 - f1: 0.4199 - val_loss: 1.3453 - val_accuracy: 0.3571 - val_f1: 0.1826
# Epoch 31/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0886 - accuracy: 0.5462 - f1: 0.4825 - val_loss: 1.3265 - val_accuracy: 0.3571 - val_f1: 0.2552
# Epoch 32/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1155 - accuracy: 0.5085 - f1: 0.3861 - val_loss: 1.2404 - val_accuracy: 0.4286 - val_f1: 0.1619
# Epoch 33/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1503 - accuracy: 0.5306 - f1: 0.3957 - val_loss: 1.2376 - val_accuracy: 0.3750 - val_f1: 0.2488
# Epoch 34/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1046 - accuracy: 0.5420 - f1: 0.4216 - val_loss: 1.2707 - val_accuracy: 0.3929 - val_f1: 0.2971
# Epoch 35/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0801 - accuracy: 0.5208 - f1: 0.3812 - val_loss: 1.2546 - val_accuracy: 0.3929 - val_f1: 0.2579
# Epoch 36/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0649 - accuracy: 0.5101 - f1: 0.4195 - val_loss: 1.1749 - val_accuracy: 0.5179 - val_f1: 0.3569
# Epoch 37/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0788 - accuracy: 0.5258 - f1: 0.4282 - val_loss: 1.1725 - val_accuracy: 0.4821 - val_f1: 0.3650
# Epoch 38/220
# 16/16 [==============================] - 0s 16ms/step - loss: 1.1008 - accuracy: 0.5038 - f1: 0.4256 - val_loss: 1.1641 - val_accuracy: 0.4107 - val_f1: 0.3795
# Epoch 39/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0828 - accuracy: 0.5323 - f1: 0.4140 - val_loss: 1.1229 - val_accuracy: 0.4286 - val_f1: 0.4514
# Epoch 40/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0659 - accuracy: 0.5352 - f1: 0.4585 - val_loss: 1.1849 - val_accuracy: 0.4107 - val_f1: 0.4397
# Epoch 41/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0990 - accuracy: 0.5428 - f1: 0.3872 - val_loss: 1.2163 - val_accuracy: 0.4286 - val_f1: 0.3441
# Epoch 42/220
# 16/16 [==============================] - 0s 16ms/step - loss: 1.0795 - accuracy: 0.5786 - f1: 0.4561 - val_loss: 1.1896 - val_accuracy: 0.4286 - val_f1: 0.3677
# Epoch 43/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0757 - accuracy: 0.5773 - f1: 0.4075 - val_loss: 1.2301 - val_accuracy: 0.3929 - val_f1: 0.3864
# Epoch 44/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1447 - accuracy: 0.5038 - f1: 0.3610 - val_loss: 1.1687 - val_accuracy: 0.4821 - val_f1: 0.4417
# Epoch 45/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1152 - accuracy: 0.5333 - f1: 0.3701 - val_loss: 1.1986 - val_accuracy: 0.4286 - val_f1: 0.3365
# Epoch 46/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0634 - accuracy: 0.5549 - f1: 0.4525 - val_loss: 1.1565 - val_accuracy: 0.5357 - val_f1: 0.3890
# Epoch 47/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.0718 - accuracy: 0.5539 - f1: 0.4017 - val_loss: 1.2522 - val_accuracy: 0.3929 - val_f1: 0.3251
# Epoch 48/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0561 - accuracy: 0.5550 - f1: 0.4785 - val_loss: 1.2121 - val_accuracy: 0.4464 - val_f1: 0.3177
# Epoch 49/220
# 16/16 [==============================] - 0s 16ms/step - loss: 1.0865 - accuracy: 0.5559 - f1: 0.3995 - val_loss: 1.3068 - val_accuracy: 0.4643 - val_f1: 0.3499
# Epoch 50/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.0988 - accuracy: 0.5133 - f1: 0.3711 - val_loss: 1.2430 - val_accuracy: 0.3750 - val_f1: 0.3107
# Epoch 51/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.1096 - accuracy: 0.5082 - f1: 0.3812 - val_loss: 1.2784 - val_accuracy: 0.4107 - val_f1: 0.2889
# Epoch 52/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0719 - accuracy: 0.5471 - f1: 0.4189 - val_loss: 1.3369 - val_accuracy: 0.4643 - val_f1: 0.3319
# Epoch 53/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.0765 - accuracy: 0.5317 - f1: 0.3922 - val_loss: 1.3288 - val_accuracy: 0.4107 - val_f1: 0.3490
# Epoch 54/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1170 - accuracy: 0.5174 - f1: 0.3728 - val_loss: 1.2901 - val_accuracy: 0.3929 - val_f1: 0.3344
# Epoch 55/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0952 - accuracy: 0.5276 - f1: 0.4230 - val_loss: 1.2876 - val_accuracy: 0.4643 - val_f1: 0.3682
# Epoch 56/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0881 - accuracy: 0.5396 - f1: 0.4212 - val_loss: 1.2090 - val_accuracy: 0.4464 - val_f1: 0.4194
# Epoch 57/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0714 - accuracy: 0.5687 - f1: 0.4063 - val_loss: 1.2509 - val_accuracy: 0.4286 - val_f1: 0.3411
# Epoch 58/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0525 - accuracy: 0.5504 - f1: 0.4646 - val_loss: 1.3059 - val_accuracy: 0.3750 - val_f1: 0.2838
# Epoch 59/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1250 - accuracy: 0.5150 - f1: 0.4015 - val_loss: 1.2268 - val_accuracy: 0.5000 - val_f1: 0.3307
# Epoch 60/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0722 - accuracy: 0.5489 - f1: 0.4378 - val_loss: 1.1900 - val_accuracy: 0.4643 - val_f1: 0.3429
# Epoch 61/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.0511 - accuracy: 0.5457 - f1: 0.4168 - val_loss: 1.1850 - val_accuracy: 0.4464 - val_f1: 0.3757
# Epoch 62/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.0419 - accuracy: 0.5498 - f1: 0.4532 - val_loss: 1.1906 - val_accuracy: 0.4464 - val_f1: 0.2592
# Epoch 63/220
# 16/16 [==============================] - 0s 16ms/step - loss: 1.0115 - accuracy: 0.5852 - f1: 0.4828 - val_loss: 1.2037 - val_accuracy: 0.4821 - val_f1: 0.3540
# Epoch 64/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.0578 - accuracy: 0.5215 - f1: 0.4469 - val_loss: 1.2314 - val_accuracy: 0.3929 - val_f1: 0.2452
# Epoch 65/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0013 - accuracy: 0.6052 - f1: 0.5063 - val_loss: 1.2072 - val_accuracy: 0.4464 - val_f1: 0.3214
# Epoch 66/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0063 - accuracy: 0.6006 - f1: 0.4839 - val_loss: 1.2359 - val_accuracy: 0.4643 - val_f1: 0.3216
# Epoch 67/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0102 - accuracy: 0.6028 - f1: 0.4918 - val_loss: 1.2291 - val_accuracy: 0.3929 - val_f1: 0.3155
# Epoch 68/220
# 16/16 [==============================] - 0s 19ms/step - loss: 0.9952 - accuracy: 0.5868 - f1: 0.4879 - val_loss: 1.2624 - val_accuracy: 0.4107 - val_f1: 0.3013
# Epoch 69/220
# 16/16 [==============================] - 0s 17ms/step - loss: 1.0043 - accuracy: 0.6093 - f1: 0.5125 - val_loss: 1.3169 - val_accuracy: 0.3571 - val_f1: 0.2947
# Epoch 70/220
# 16/16 [==============================] - 0s 18ms/step - loss: 0.9786 - accuracy: 0.6083 - f1: 0.5264 - val_loss: 1.2958 - val_accuracy: 0.4643 - val_f1: 0.3625
# Epoch 71/220
# 16/16 [==============================] - 0s 17ms/step - loss: 0.9544 - accuracy: 0.6421 - f1: 0.5616 - val_loss: 1.3052 - val_accuracy: 0.3393 - val_f1: 0.3205
# Epoch 72/220
# 16/16 [==============================] - 0s 17ms/step - loss: 0.9605 - accuracy: 0.6056 - f1: 0.5590 - val_loss: 1.3477 - val_accuracy: 0.3750 - val_f1: 0.3438
# Epoch 73/220
# 16/16 [==============================] - 0s 16ms/step - loss: 1.0004 - accuracy: 0.5839 - f1: 0.5136 - val_loss: 1.3558 - val_accuracy: 0.3571 - val_f1: 0.2957
# Epoch 74/220
# 16/16 [==============================] - 0s 18ms/step - loss: 0.9836 - accuracy: 0.6014 - f1: 0.5373 - val_loss: 1.3193 - val_accuracy: 0.3929 - val_f1: 0.2532
# Epoch 75/220
# 16/16 [==============================] - 0s 18ms/step - loss: 1.0035 - accuracy: 0.5961 - f1: 0.4877 - val_loss: 1.2677 - val_accuracy: 0.4107 - val_f1: 0.3229
# Epoch 76/220
# 16/16 [==============================] - 0s 17ms/step - loss: 0.9464 - accuracy: 0.6334 - f1: 0.5518 - val_loss: 1.3217 - val_accuracy: 0.4107 - val_f1: 0.3410
# Epoch 77/220
# 16/16 [==============================] - 0s 16ms/step - loss: 0.9669 - accuracy: 0.6109 - f1: 0.5537 - val_loss: 1.3228 - val_accuracy: 0.3571 - val_f1: 0.3128
# Epoch 78/220
# 16/16 [==============================] - 0s 18ms/step - loss: 0.9753 - accuracy: 0.6096 - f1: 0.5517 - val_loss: 1.2456 - val_accuracy: 0.4643 - val_f1: 0.3908
# Epoch 79/220
# 16/16 [==============================] - 0s 17ms/step - loss: 0.9608 - accuracy: 0.6243 - f1: 0.5280 - val_loss: 1.2993 - val_accuracy: 0.3929 - val_f1: 0.3239

# %%
model_FC.load_weights(model_name_fcn)
loss_FC = model_FC.evaluate(X_test, Y_test_oh, verbose=0)
print('Final loss (cross-entropy and accuracy, F1):',loss_FC)

plt.plot(history_FC.history['loss'], label = "Train loss")
plt.plot(history_FC.history['val_loss'], label = "Val loss")
plt.xlabel("Epoch (iteration)")
plt.ylabel("Loss")
plt.legend()
plt.grid()
plt.show()


plt.plot(history_FC.history['accuracy'], label = "Train accuarcy")
plt.plot(history_FC.history['val_accuracy'], label = "Val accuarcy")
plt.xlabel("Epoch (iteration)")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()
plt.show()

plt.plot(history_FC.history['f1'], label = "Train F1")
plt.plot(history_FC.history['val_f1'], label = "Val F1")
plt.xlabel("Epoch (iteration)")
plt.ylabel("F1")
plt.legend()
plt.grid()
plt.show()
# Out:
# Final loss (cross-entropy and accuracy, F1): [1.3039954900741577, 0.3650793731212616, 0.2782268822193146]
